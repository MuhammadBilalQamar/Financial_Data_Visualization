# %%
# %matplotlib inline
import pandas as pd # Import for Pandas
import numpy as np # Import for Numpy
import matplotlib # Import for Matplotlib
import matplotlib.pyplot as plt # Import for Matplotlib Pyplot
import seaborn as sns # Import for Seaborn

# %% [markdown]
# Downloading the dataset...
#
#
# What kind or information you'll get ?
# The download will include information about your:
#
# 1. Identity
# 2. Inferences
# 3. User Data
# 4. Playlists
# 5. Streaming History
# 6. Searches
# 7. List of items saved in Your Library
# 8. Number of followers you have
# 9. Number of accounts you follow
# 10. Names of the artists you follow
# 11. Payment and subscription data.

# %%
df = pd.read_json("/content/StreamingHistory0.json") # Load the JSON File into a dataframe
df.head() # Read first few lines of the dataframe
# Out:
#             endTime                    artistName  \
# 0  2021-06-19 13:40                       Blxckie
# 1  2021-06-24 06:33  The Positive Mindset Podcast
# 2  2021-06-25 08:18  The Positive Mindset Podcast
# 3  2021-06-26 06:54                   London Real
# 4  2021-06-26 15:41                       Blxckie
#
#                                            trackName  msPlayed
# 0                                              Ye x4    166280
# 1   Shifting from a Negative to a Positive Mindset!     639582
# 2    What would a Positive Mindset would do for you!    625266
# 3  James Clear - Atomic Habits: How Tiny Changes ...    321624
# 4                                              Ye x4       970

# %%
#Import data
df1 = pd.read_json("/content/StreamingHistory0.json") # Read the first file

# %%
df1.head() # To read top 5 rows of the first dataframe
# Out:
#             endTime                    artistName  \
# 0  2021-06-19 13:40                       Blxckie
# 1  2021-06-24 06:33  The Positive Mindset Podcast
# 2  2021-06-25 08:18  The Positive Mindset Podcast
# 3  2021-06-26 06:54                   London Real
# 4  2021-06-26 15:41                       Blxckie
#
#                                            trackName  msPlayed
# 0                                              Ye x4    166280
# 1   Shifting from a Negative to a Positive Mindset!     639582
# 2    What would a Positive Mindset would do for you!    625266
# 3  James Clear - Atomic Habits: How Tiny Changes ...    321624
# 4                                              Ye x4       970

# %%
df1.tail() # To read bottom 5 rows of the first dataframe
# Out:
#                endTime   artistName                      trackName  msPlayed
# 5675  2022-06-24 21:01       WizKid  Blessed (feat. Damian Marley)    262973
# 5676  2022-06-24 21:05         Tyla                   Getting Late    254557
# 5677  2022-06-24 21:09  Blinky Bill           Jam Now, Simmer Down    198930
# 5678  2022-06-24 21:15      Souloho                      Labelungu    245818
# 5679  2022-06-24 21:25    BenjiFlow                             Go     14442

# %%
#Merging all of the data together
spotify_stream_df = pd.concat([df1], ignore_index=True) # To concatenate the two dataframes
spotify_stream_df.to_csv("spotify_data_0.csv") # To save csv data

# %%
spotify_stream_df # To read all the dataframe at once
# Out:
#                endTime                    artistName  \
# 0     2021-06-19 13:40                       Blxckie
# 1     2021-06-24 06:33  The Positive Mindset Podcast
# 2     2021-06-25 08:18  The Positive Mindset Podcast
# 3     2021-06-26 06:54                   London Real
# 4     2021-06-26 15:41                       Blxckie
# ...                ...                           ...
# 5675  2022-06-24 21:01                        WizKid
# 5676  2022-06-24 21:05                          Tyla
# 5677  2022-06-24 21:09                   Blinky Bill
# 5678  2022-06-24 21:15                       Souloho
# 5679  2022-06-24 21:25                     BenjiFlow
#
#                                               trackName  msPlayed
# 0                                                 Ye x4    166280
# 1      Shifting from a Negative to a Positive Mindset!     639582
# 2       What would a Positive Mindset would do for you!    625266
# 3     James Clear - Atomic Habits: How Tiny Changes ...    321624
# 4                                                 Ye x4       970
# ...                                                 ...       ...
# 5675                      Blessed (feat. Damian Marley)    262973
# 5676                                       Getting Late    254557
# 5677                               Jam Now, Simmer Down    198930
# 5678                                          Labelungu    245818
# 5679                                                 Go     14442
#
# [5680 rows x 4 columns]

# %%
spotify_stream_df.shape
# Out:
# (5680, 4)

# %%
spotify_stream_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5680 entries, 0 to 5679
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   endTime     5680 non-null   object
#  1   artistName  5680 non-null   object
#  2   trackName   5680 non-null   object
#  3   msPlayed    5680 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 177.6+ KB

# %%
spotify_stream_df.nunique() # To see the unique elemetns present in each column
# Out:
# endTime       3061
# artistName     777
# trackName     1796
# msPlayed      3839
# dtype: int64

# %%
spotify_stream_df.sample(10) # To check a sample of the data
# Out:
#                endTime           artistName  \
# 498   2021-09-28 17:45                 Tyla
# 4712  2022-05-27 19:21            Burna Boy
# 4453  2022-05-19 12:39         Fall Out Boy
# 2475  2022-01-26 09:04       D-Block Europe
# 5655  2022-06-24 20:19               Davido
# 178   2021-07-28 09:45        Amy Winehouse
# 3294  2022-03-17 12:41           Kali Uchis
# 5060  2022-06-09 13:16  Megan Thee Stallion
# 1995  2022-01-07 17:47           KAYTRANADA
# 38    2021-07-03 11:39              Blxckie
#
#                                               trackName  msPlayed
# 498                  Overdue (feat. DJ Lag & Kooldrink)    226813
# 4712                                           JA ARA E      2280
# 4453                                   Sunshine Riptide         0
# 2475                                           Overseas      3194
# 5655          Stand Strong (feat. Sunday Service Choir)       870
# 178                              Tears Dry On Their Own    183767
# 3294  After The Storm (feat. Tyler, The Creator & Bo...      1337
# 5060                                       Captain Hook      1330
# 1995                                     YOU'RE THE ONE      5192
# 38                                                Ye x4    144010

# %%
len(spotify_stream_df["artistName"].unique()) # Length of unique artist
# Out:
# 777

# %%
len(spotify_stream_df["trackName"].unique()) # Length of unique tracks
# Out:
# 1796

# %%
#Cleaning and formatting
spotify_stream_df["Play-Time"]= pd.to_datetime(spotify_stream_df["endTime"]) # To create a additional column

# %%
spotify_stream_df['year'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).year
spotify_stream_df['month'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).month
spotify_stream_df['day'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).day
spotify_stream_df['weekday'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).weekday
spotify_stream_df['time'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).time
spotify_stream_df['hours'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).hour
spotify_stream_df['day-name'] = spotify_stream_df["Play-Time"].apply(lambda x: x.day_name())
spotify_stream_df['Count'] = 1

# %% [markdown]
# Here we used the DatetimeIndex module to obatin the several unique information. We also added them to a new columns as per their representaion and information.
#
# Information contained in different columns :
#
# 1. year has information about the year when we played that song
# 2. month has information about the month when we played that song
# 3. weekday has information about the weekday when we played that song
# 4. time has information about the time when we played that song
# 5. hours has information about the hour when we played that song
# 6. day-name has information about the day with the name when we played that
# 7.  song. Here we used apply method for pandas dataframe with lambda function.

# %%
spotify_stream_df["Time-Played (hh-mm-ss)"] = pd.to_timedelta(spotify_stream_df["msPlayed"], unit='ms')

# %%
def hours(td):
    '''To get the hour information'''
    return td.seconds/3600

def minutes(td):
    '''To get the minutes information'''
    return (td.seconds/60)%60

spotify_stream_df["Listening Time(Hours)"] = spotify_stream_df["Time-Played (hh-mm-ss)"].apply(hours).round(3)
spotify_stream_df["Listening Time(Minutes)"] = spotify_stream_df["Time-Played (hh-mm-ss)"].apply(minutes).round(3)

# %%
spotify_stream_df.head() # To check the newly formed dataset with additional columns
# Out:
#             endTime                    artistName  \
# 0  2021-06-19 13:40                       Blxckie
# 1  2021-06-24 06:33  The Positive Mindset Podcast
# 2  2021-06-25 08:18  The Positive Mindset Podcast
# 3  2021-06-26 06:54                   London Real
# 4  2021-06-26 15:41                       Blxckie
#
#                                            trackName  msPlayed  \
# 0                                              Ye x4    166280
# 1   Shifting from a Negative to a Positive Mindset!     639582
# 2    What would a Positive Mindset would do for you!    625266
# 3  James Clear - Atomic Habits: How Tiny Changes ...    321624
# 4                                              Ye x4       970
#
#             Play-Time  year  month  day  weekday      time  hours  day-name  \
# 0 2021-06-19 13:40:00  2021      6   19        5  13:40:00     13  Saturday
# 1 2021-06-24 06:33:00  2021      6   24        3  06:33:00      6  Thursday
# 2 2021-06-25 08:18:00  2021      6   25        4  08:18:00      8    Friday
# 3 2021-06-26 06:54:00  2021      6   26        5  06:54:00      6  Saturday
# 4 2021-06-26 15:41:00  2021      6   26        5  15:41:00     15  Saturday
#
#    Count Time-Played (hh-mm-ss)  Listening Time(Hours)  \
# 0      1 0 days 00:02:46.280000                  0.046
# 1      1 0 days 00:10:39.582000                  0.178
# 2      1 0 days 00:10:25.266000                  0.174
# 3      1 0 days 00:05:21.624000                  0.089
# 4      1 0 days 00:00:00.970000                  0.000
#
#    Listening Time(Minutes)
# 0                    2.767
# 1                   10.650
# 2                   10.417
# 3                    5.350
# 4                    0.000

# %% [markdown]
# Drop columns that are not useful

# %%
spotify_stream_df.drop(columns=["endTime","Time-Played (hh-mm-ss)","msPlayed"], inplace=True)

# %%
spotify_stream_df.describe() # Final check for any abnormality
# Out:
#               year        month          day      weekday        hours  \
# count  5680.000000  5680.000000  5680.000000  5680.000000  5680.000000
# mean   2021.676761     5.825352    16.843662     2.319894    12.268310
# std       0.467754     3.445670     8.426799     1.658020     3.861739
# min    2021.000000     1.000000     1.000000     0.000000     4.000000
# 25%    2021.000000     3.000000    11.000000     1.000000     9.000000
# 50%    2022.000000     5.000000    17.000000     2.000000    12.000000
# 75%    2022.000000     9.000000    24.000000     3.000000    15.000000
# max    2022.000000    12.000000    31.000000     6.000000    23.000000
#
#         Count  Listening Time(Hours)  Listening Time(Minutes)
# count  5680.0            5680.000000              5680.000000
# mean      1.0               0.021872                 1.314105
# std       0.0               0.029892                 1.791574
# min       1.0               0.000000                 0.000000
# 25%       1.0               0.000000                 0.017000
# 50%       1.0               0.005000                 0.300000
# 75%       1.0               0.041000                 2.433000
# max       1.0               0.354000                21.217000

# %%
top_10_artist_df = spotify_stream_df.groupby(["artistName"])[["Listening Time(Hours)","Listening Time(Minutes)","Count"]].sum().sort_values(by="Listening Time(Minutes)",ascending=False)
top_10_artist_df.head(15)
# Out:
#                               Listening Time(Hours)  Listening Time(Minutes)  \
# artistName
# Tyla                                          9.771                  584.937
# The Positive Mindset Podcast                  6.707                  402.181
# Kendrick Lamar                                5.787                  348.538
# Burna Boy                                     4.274                  257.430
# Baby Keem                                     4.277                  256.320
# KAYTRANADA                                    4.113                  246.551
# Tinashe                                       3.664                  219.597
# BIA                                           2.960                  177.272
# WizKid                                        2.927                  175.907
# Normani                                       2.923                  175.454
# Alfa Kat                                      2.631                  158.301
# DJ Maphorisa                                  2.552                  153.137
# Busta 929                                     2.193                  131.516
# Drake                                         2.090                  125.758
# SZA                                           2.060                  123.418
#
#                               Count
# artistName
# Tyla                            192
# The Positive Mindset Podcast     83
# Kendrick Lamar                  253
# Burna Boy                       201
# Baby Keem                        83
# KAYTRANADA                      162
# Tinashe                         164
# BIA                             138
# WizKid                          110
# Normani                          90
# Alfa Kat                         61
# DJ Maphorisa                     45
# Busta 929                        47
# Drake                            85
# SZA                              68

# %%
top_10_artist_time_df = spotify_stream_df.groupby(["artistName"])[["Listening Time(Hours)","Listening Time(Minutes)","Count"]].sum().sort_values(by="Listening Time(Minutes)",ascending=False)
top_10_artist_time_df.head(10)
# Out:
#                               Listening Time(Hours)  Listening Time(Minutes)  \
# artistName
# Tyla                                          9.771                  584.937
# The Positive Mindset Podcast                  6.707                  402.181
# Kendrick Lamar                                5.787                  348.538
# Burna Boy                                     4.274                  257.430
# Baby Keem                                     4.277                  256.320
# KAYTRANADA                                    4.113                  246.551
# Tinashe                                       3.664                  219.597
# BIA                                           2.960                  177.272
# WizKid                                        2.927                  175.907
# Normani                                       2.923                  175.454
#
#                               Count
# artistName
# Tyla                            192
# The Positive Mindset Podcast     83
# Kendrick Lamar                  253
# Burna Boy                       201
# Baby Keem                        83
# KAYTRANADA                      162
# Tinashe                         164
# BIA                             138
# WizKid                          110
# Normani                          90

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.bar(top_10_artist_time_df.head(10).index,top_10_artist_time_df["Listening Time(Hours)"].head(10),color='green')
ax.set(title="My Top 10 Favourite Artist (based on Hours)",xlabel="Artists",ylabel="No. of Hours Songs Played");
plt.xticks(rotation=90);

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.pie(spotify_stream_df["day-name"].value_counts(), labels=spotify_stream_df["day-name"].value_counts().index, autopct='%1.1f%%', startangle=180, shadow = True);
ax.set(title="Day wise % of Spotify Streaming");

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.set(title="Average Distribution of Streaming Over Day Hours",xlabel="Hours (in 24 hour format)", ylabel="Songs Played")
sns.histplot(spotify_stream_df["hours"], bins=24,kde=True, color="darkgreen");

# %%
fig, ax = plt.subplots(figsize=(20,10))

ax = sns.countplot(y=spotify_stream_df["month"], ax=ax)
ax.set(title="Average Spotify Usage over Years", xlabel="Songs Played in Counts", ylabel="Months (Jan-Dec)");

# %%
#Create two seperate files that show amount of listens and then artist and then songs
# Out:
# Index(['Unnamed: 0', 'endTime', 'artistName', 'trackName', 'msPlayed'], dtype='object')
